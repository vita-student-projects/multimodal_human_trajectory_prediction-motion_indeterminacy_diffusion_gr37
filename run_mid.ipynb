# %%
#INSTALL CONDA ON COLLAB
# %env PYTHONPATH=
# !echo $PYTHONPATH
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/
# Out:
# env: PYTHONPATH=
#
# --2023-05-31 10:49:33--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104996770 (100M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh’
#
# Miniconda3-py37_4.1 100%[===================>] 100.13M   364MB/s    in 0.3s
#
# 2023-05-31 10:49:33 (364 MB/s) - ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh’ saved [104996770/104996770]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py37h06a4308_2
# ...

# %%
import sys
sys.path
# !ls /usr/local/lib/python3.7/dist-packages
sys.path.append("/usr/local/lib/python3.7/site-packages")
# Out:
# ls: cannot access '/usr/local/lib/python3.7/dist-packages': No such file or directory

# %%
#CONNECT TO GOOGLE DRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext autoreload

# %%
# You need to replace "drive/MyDrive/DLAV-2023/MID/" in the following commands with your directory

# %%
#CREATE THE ENVIRONNEMENT
# !conda env create --file=drive/MyDrive/DLAV-2023/MID/env/mid_env.yaml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ...
# numpy-base-1.19.2    | 4.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.31it/s]
# ca-certificates-2021 | 116 KB    | : 100% 1.0/1 [00:00<00:00, 17.09it/s]
# setuptools-52.0.0    | 710 KB    | : 100% 1.0/1 [00:00<00:00,  5.82it/s]
# sqlite-3.33.0        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00, 11.46it/s]
# pytorch-1.7.1        | 771.1 MB  | : 100% 1.0/1 [01:58<00:00, 118.57s/it]
# readline-8.1         | 362 KB    | : 100% 1.0/1 [00:00<00:00, 13.72it/s]
# mkl-service-2.3.0    | 52 KB     | : 100% 1.0/1 [00:00<00:00, 16.15it/s]
# intel-openmp-2020.2  | 786 KB    | : 100% 1.0/1 [00:00<00:00, 14.95it/s]
# openssl-1.1.1l       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  7.87it/s]
# mkl_random-1.1.1     | 322 KB    | : 100% 1.0/1 [00:00<00:00, 16.54it/s]
# ...

# %%
#RELOAD FILES IF CHANGED/MODIFIED
# %load_ext autoreload
# !source activate mid && %load_ext autoreload
# !source activate mid && %autoreload 2
# %autoreload 2
# %reload_ext autoreload
print('ok')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /bin/bash: line 0: fg: no job control
# /bin/bash: line 0: fg: no job control
# ok

# %%
# !source activate mid && pip install --upgrade pandas

# %%
# PROCESS DATA FOR THE PEDESTRIAN DATASETS (ETH/UCY)
#!source activate mid && python drive/MyDrive/DLAV-2023/MID/process_data_pedestrians.py

# %%
#RUN MODEL ON ETH
#!source activate mid && python drive/MyDrive/DLAV-2023/MID/main.py --config drive/MyDrive/DLAV-2023/MID/configs/baseline.yaml --dataset "eth "

# %%
# PROCESS DATA FOR THE NUSCENES DATASET
# CHOOSE THE PROPORTION OF DATA YOU WANT TO TRAIN IN process_data.py
# !pip install -r requirements.txt
# !python drive/MyDrive/DLAV-2023/MID/process_data_nuscenes.py --data=./v1.0 --version="v1.0-trainval" --output_path=drive/MyDrive/DLAV-2023/MID/processed_data_noise

# %%
#RUN AND EVALUATE THE MODEL ON NUSCENES
#CHANGE PREDICTION HORIZON IN THE FILE : trajectron_hypers.py 
#CHANGE OTHER PARAMETERS IN THE files nuscenes.yaml 
# !source activate mid && python drive/MyDrive/DLAV-2023/MID/main.py --config drive/MyDrive/DLAV-2023/MID/configs/nuscenes.yaml --dataset "nuscenes "
# Out:
# config dataset : nuscenes
# What sampling ? : ddpm
# > Directory built!
# self.model_dir : drive/MyDrive/DLAV-2023/MID/experiments/nuscenes
# Loading Encoder
# > Model built!
# > Dataset built!
# > Optimizer built!
# > Everything built. Have fun :)
# EVAL
# SAMPLING : ddpm
# PH : 8
# ----- Evaluating Scene 1/15
# 100% 4/4 [00:00<00:00,  4.75it/s]
# ----- Evaluating Scene 2/15
# 100% 4/4 [00:00<00:00, 19737.90it/s]
# ----- Evaluating Scene 3/15
# 100% 4/4 [00:00<00:00, 29799.67it/s]
# ----- Evaluating Scene 4/15
# 100% 4/4 [00:00<00:00, 29537.35it/s]
# ----- Evaluating Scene 5/15
# 100% 4/4 [00:00<00:00, 23045.63it/s]
# ----- Evaluating Scene 6/15
# 100% 4/4 [00:00<00:00,  4.59it/s]
# ----- Evaluating Scene 7/15
# 100% 4/4 [00:01<00:00,  2.93it/s]
# ----- Evaluating Scene 8/15
# 100% 4/4 [00:01<00:00,  2.04it/s]
# ----- Evaluating Scene 9/15
# 100% 4/4 [00:00<00:00, 8405.42it/s]
# ----- Evaluating Scene 10/15
# 100% 4/4 [00:00<00:00, 4534.38it/s]
# ----- Evaluating Scene 11/15
# ...
